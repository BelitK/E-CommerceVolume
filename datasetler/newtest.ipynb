# %%
from fbprophet import Prophet
import pandas as pd
from pandas import DataFrame
from matplotlib import pyplot
#univariate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-b1c89e91dbad> in <module>
# ----> 1 from fbprophet import Prophet
#       2 import pandas as pd
#       3 from pandas import DataFrame
#       4 from matplotlib import pyplot
#       5 #univariate
#
# ModuleNotFoundError: No module named 'fbprophet'

# %%
turkey = pd.read_excel("TurkeyData.xlsx",header=0)
turkey.plot()
print(turkey.shape)
pyplot.show()
# Out:
# (39, 2)

# %%
turkey.columns = ['ds', 'y']
turkey
turkey['ds']= pd.to_datetime(turkey['ds'])

# %%
model = Prophet()

# %%
model.fit(turkey)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# define the period for which we want a prediction
future = list()
for i in range(1,13,3):
	date = '2023-%02d' % i
	future.append([date])
future = DataFrame(future)
future.columns = ['ds']
future['ds']= pd.to_datetime(future['ds'])
# use the model to make a forecast
forecast = model.predict(future)
# summarize the forecast
print(forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']])
# plot forecast
model.plot(forecast)
pyplot.show()
# Out:
#           ds           yhat     yhat_lower     yhat_upper
# 0 2023-01-01  181601.405781  174003.131643  189095.823600
# 1 2023-04-01  188187.429927  180465.479630  196103.345740
# 2 2023-07-01  197399.786436  189167.045491  205659.826713
# 3 2023-10-01  200779.079616  191441.034888  210712.256492

# %%
# create test dataset, remove last 12 months
train = turkey.drop(turkey.index[-12:])
print(train.tail())
model.plot_components(forecast)
# Out:
#            ds         y
# 22 2016-07-01  35564.10
# 23 2016-10-01  36377.03
# 24 2017-01-01  41252.10
# 25 2017-04-01  47138.21
# 26 2017-07-01  56096.90

# %%
from sklearn.metrics import mean_absolute_error
# calculate MAE between expected and predicted values for december
y_true = turkey['y'][-12:].values
y_pred = forecast['yhat'][-2:].values
mae = mean_absolute_error(y_true, y_pred)
print('MAE: %.3f' % mae)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-158-a886d55f86a5> in <module>
#       3 y_true = turkey['y'][-12:].values
#       4 y_pred = forecast['yhat'][-2:].values
# ----> 5 mae = mean_absolute_error(y_true, y_pred)
#       6 print('MAE: %.3f' % mae)
#
# ~/anaconda3/envs/bigdataodev/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/anaconda3/envs/bigdataodev/lib/python3.8/site-packages/sklearn/metrics/_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     176     0.85...
#     177     """
# --> 178     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     179         y_true, y_pred, multioutput)
#     180     check_consistent_length(y_true, y_pred, sample_weight)
#
# ~/anaconda3/envs/bigdataodev/lib/python3.8/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      82
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      86     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~/anaconda3/envs/bigdataodev/lib/python3.8/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     253     uniques = np.unique(lengths)
#     254     if len(uniques) > 1:
# --> 255         raise ValueError("Found input variables with inconsistent numbers of"
#     256                          " samples: %r" % [int(l) for l in lengths])
#     257
#
# ValueError: Found input variables with inconsistent numbers of samples: [12, 2]

# %%
# plot expected vs actual
pyplot.plot(y_true, label='Actual')
pyplot.plot(y_pred, label='Predicted')
pyplot.legend()
pyplot.show()
